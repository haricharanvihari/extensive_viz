# %% [markdown]
# <a href="https://colab.research.google.com/github/haricharanvihari/extensive_viz/blob/master/S15_DNN/utils/overlay_mask_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Custom dataset for monocular depth estimation and segmentation

# %% [markdown]
# ## GIT Repo Folder Structure
#
#     --fg_bg_dataset
#       --fg                        # Forground Images
#         --fg_001.png
#         --fg_002.png
#         -- ...
#       --bg                        # Background Images
#         --bg_001.png
#         --bg_002.png
#         -- ...
#       --fg_mask                   # Mask Images for fg
#         --mask_fg_001.png
#         --mask_fg_002.png
#         -- ...
#       --utils                     # Utility functions
#         --image_resize.py
#         --rename.py
#         --overlay.py
#         --mask.py
#       --bgfg_overlay              # Overlay Images
#       --bgfg_mask                 # Mask for Overlay Images

# %%
cd fg_bg_dataset/
# Out:
# [Errno 2] No such file or directory: 'fg_bg_dataset/'
# /content/fg_bg_dataset

# %%
# !git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
ls
# Out:
# bg/  bgfg_mask/  bgfg_overlay/  fg/  fg_mask/

# %%
ls /content/gdrive/'My Drive'/EVA/S15/bgfg_mask/

# %%
from utils.overlay import overlay_fg_on_bg

input_folder = "/content/fg_bg_dataset/"
output_folder = "/content/fg_bg_dataset/"

overlay_fg_on_bg(input_folder, output_folder)
# Out:
# Processing bg99.jpg for FG fg100.png: : 100it [26:47, 16.08s/it]

# %%
# !zip -r maskrcnndataset_overlay.zip /content/gdrive/'My Drive'/EVA/S15/bgfg_overlay

# %%
# !zip -r maskrcnndataset_mask.zip /content/gdrive/'My Drive'/EVA/S15/bgfg_mask/

# %%
from IPython.display import Image
Image(filename="/content/gdrive/'My Drive'/EVA/S15/fg/fg79.png", width=200)

# %%
from IPython.display import Image
Image(filename='/content/fg_bg_dataset/fg_mask/mask_fg_079.png', width=200)

# %%
from IPython.display import Image
Image(filename='/content/fg_bg_dataset/bg/bg_019.jpg', width=200)

# %%
from IPython.display import Image
Image(filename='/content/fg_bg_dataset/bgfg_mask/mask_ol_bg019fg07917_fg_079.png', width=200)

# %%
from IPython.display import Image
