# %% [markdown]
# <a href="https://colab.research.google.com/github/haricharanvihari/extensive_viz/blob/master/S13_DNN/S13_EVA4S13F13_YoloV3_Haricharan_Vihari_N_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# fatal: destination path 'YoloV3' already exists and is not an empty directory.

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
#  annotation_tool/   output/        results.txt        train.py
#  cfg/               predict/       runs/             'ubdivisions=1'
#  data/              __pycache__/   test_batch0.png    utils/
#  detect.py          README.md      test.py            vim.exe.stackdump
#  models.py          results.json   ting               weights/
#  out_out/           results.png    train_batch0.png

# %%
cd YoloV3/
# Out:
# [Errno 2] No such file or directory: 'YoloV3/'
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   predict	  runs		    'ubdivisions=1'
#  data		   __pycache__	  test_batch0.png    utils
#  detect.py	   README.md	  test.py	     vim.exe.stackdump
#  models.py	   results.json   ting		     weights
#  out_out	   results.png	  train_batch0.png

# %%
# !python train.py --data /content/YoloV3/data/customdata/custom.data --cache --epochs 300 --weights /content/YoloV3/weights/yolov3-spp-ultralytics.pt --cfg /content/YoloV3/cfg/yolov3-custom.cfg
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/YoloV3/cfg/yolov3-custom.cfg', data='/content/YoloV3/data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='/content/YoloV3/weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-05 21:06:40.075668: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 4.4214e+07 parameters, 4.4214e+07 gradients
# Caching labels (500 found, 0 missing, 0 empty, 0 duplicate, for 500 images): 100% 500/500 [00:00<00:00, 10603.89it/s]
# Caching images (0.3GB): 100% 500/500 [00:02<00:00, 189.30it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 4.4214e+07 parameters, 4.4214e+07 gradients
# image 1/500 data/customdata/images/img0.jpg: 320x512 1 jacks, Done. (0.020s)
# image 2/500 data/customdata/images/img1.jpg: 512x448 1 jacks, Done. (0.024s)
# image 3/500 data/customdata/images/img10.jpg: 512x512 1 jacks, Done. (0.025s)
# image 4/500 data/customdata/images/img100.jpg: 512x320 1 jacks, Done. (0.020s)
# image 5/500 data/customdata/images/img101.jpg: 384x512 1 jacks, Done. (0.021s)
# image 6/500 data/customdata/images/img102.jpg: 320x512 1 jacks, Done. (0.019s)
# ...

# %%
Image(filename='out_out/img496.jpg', width=600)
